# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
import numpy as np

# %%
from sklearn.preprocessing import StandardScaler

# %%
std = StandardScaler()

# %%
data = pd.read_excel('123.xlsx')
data.head()
# Out:
#    Quantity  Q_firms  Q_worker    IPP  Q_ed_inst    Invest  Population  \
# 0   15364.6    11723      83.8  116.1       1529   37611.2       278.4
# 1   18687.1     7180      58.4  105.6        298   20212.6       179.8
# 2   48794.7    41923     200.8  121.0       1212  112114.2       622.7
# 3   31208.5    27228     193.6  116.9        891   51310.7       585.6
# 4   10679.4     8082      76.9  120.0        749   31974.4       221.1
#
#    perc_work     Area
# 0       30.1  129.870
# 1       32.5  362.140
# 2       32.2  331.160
# 3       33.1  388.735
# 4       34.8  320.970

# %%
X = np.array(data.iloc[:,1:9])
y = np.array(data.iloc[:,0])

# %%
X.shape
# Out:
# (78, 8)

# %%
y.shape
# Out:
# (78,)

# %%
X = std.fit_transform(X,y)

# %%
lr = LinearRegression(normalize=True,fit_intercept=0)

# %%
lr.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=0, n_jobs=1, normalize=True)

# %%
lr.coef_
# Out:
# array([-9.41782592e-01,  7.97014112e+02, -1.58844372e-01])

# %%
from sklearn.metrics import r2_score, accuracy_score

# %%
r2_score(y, lr.predict(X))
# Out:
# 0.5181480159062888

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

corr = data.corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %%
# %config InlineBackend.figure_format = 'retina'
